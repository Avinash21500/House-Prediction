# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('C:/Users/This PC/HousePrediction/housing.csv', delimiter= '\s+', names=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MDEV'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MDEV       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB

# %%
sns.heatmap(train.isnull())

# %%
sns.distplot(train['CRIM'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['ZN'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['INDUS'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['CHAS'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['NOX'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['RM'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['AGE'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['DIS'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['RAD'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['TAX'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['PTRATIO'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['B'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(train['LSTAT'].dropna(),kde=True,bins=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
x=train.drop("MDEV",axis=1)
y=train['MDEV']

# %%
from sklearn.cross_validation import train_test_split
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictios=lm.predict(X_test)

# %%
predictios
# Out:
# array([40.11113508, 27.38971873, 16.64700435, 16.98475572, 31.12920137,
#        32.17489772, 38.5534506 ,  8.16734819, 33.48547457,  7.21877263,
#        30.45404514, 13.44085219, 16.25354375, 17.34359227, 25.1543491 ,
#        20.44171457,  7.30340549, 33.13892161, 28.41293108, 24.58522513,
#        12.44673568, 20.25489284, 22.48601345, 24.42119495, 33.92740928,
#        18.63104614, 32.32820984, 18.67352155, 27.36115374, 34.46174375,
#        19.84089751, 18.40373436, 37.15821555, 44.94610923, 30.27513579,
#        22.00760066, 16.0127978 , 18.16328402,  4.33298095, 30.93867591,
#        24.15262229, 17.17277775, 34.10334259, 13.89433899, 17.46893797,
#        25.30893285, 30.35309561, 16.10339452, 26.91513852, 22.98227547,
#        32.14815603, 37.34454946, 22.90074019, 17.56894548, 30.18430234,
#         0.10360753, 20.22573888, 16.82248142, 23.15487984, 21.16760077,
#        30.5734497 ,  3.15502223, 15.92340596, 20.06361892, 10.43608925,
# ...

# %%
print(lm.coef_)
# Out:
# [-8.85049752e-02  5.02928536e-02  2.03483110e-02  3.75427054e+00
#  -1.77483714e+01  3.24776492e+00  1.20008182e-02 -1.40916141e+00
#   2.63880691e-01 -1.03440009e-02 -9.51780874e-01  6.11600491e-03
#  -5.97133217e-01]

# %%
print(lm.intercept_)
# Out:
# 40.21892901255104

# %%
print(y_test)
# Out:
# 195    50.0
# 4      36.2
# 434    11.7
# 458    14.9
# 39     30.8
# 304    36.1
# 225    50.0
# 32     13.2
# 157    41.3
# 404     8.5
# 65     23.5
# 138    13.3
# 18     20.2
# 352    18.6
# 114    18.5
# 407    27.9
# 417    10.4
# 290    28.5
# 95     28.4
# 321    23.1
# 439    12.8
# 12     21.7
# 505    11.9
# 252    29.6
# 291    37.3
# 361    19.9
# 234    29.0
# 128    18.0
# 372    50.0
# 198    34.6
#        ...
# 255    20.9
# 274    32.4
# 56     24.7
# 480    23.0
# 427    10.9
# 388    10.2
# 156    13.1
# 53     23.4
# 311    22.1
# 189    34.9
# 51     20.5
# 494    24.5
# 473    29.8
# 165    25.0
# 236    25.1
# 240    22.0
# 228    46.7
# 322    20.4
# 435    13.4
# 202    42.3
# 179    37.2
# 133    18.4
# 251    24.8
# 15     19.9
# 13     20.4
# 213    28.1
# 269    20.7
# 278    29.1
# 17     17.5
# 391    23.2
# Name: MDEV, Length: 152, dtype: float64

# %%
print(np.mean((predictios-y_test)**2))
# Out:
# 28.54758527146807

# %%
from sklearn.metrics import mean_squared_error

# %%
print(mean_squared_error(y_test, predictios))
# Out:
# 28.547585271468062
